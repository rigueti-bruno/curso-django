# %% [markdown]
# ## Funções no Python

# %%
def enviar_email(nome,email):
    email_orig = 'pycode@gmail.com'
    senha = '12345'
    nome_dest = nome
    email_dest = email
    return f'Email enviado para {nome_dest}, dono do email {email}.'

pessoas = ['Felipe','Gabriele','Joao']

for pessoa in pessoas:
    email_enviado = enviar_email(pessoa, f'{pessoa.lower()}@gmail.com')
    print(email_enviado)
# Out:
# Email enviado para Felipe, dono do email felipe@gmail.com.
# Email enviado para Gabriele, dono do email gabriele@gmail.com.
# Email enviado para Joao, dono do email joao@gmail.com.

# %%
def somar(a,b):
    resultado = a + b
    return resultado

soma = somar(77,55)
print(soma)
# Out:
# 132
